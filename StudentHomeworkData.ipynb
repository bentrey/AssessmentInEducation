# %%
import random

#This class will simulate a students performance 
class Student:
    def __init__(self, school_quailty):
        #mathAbility represents a student's baseline math skills
        self.math_ability = school_quailty - 1.0 + 2.0*random.random()
        #intelligence represents a student's potential for growth
        self.intelligence = school_quailty - 1.0 + 2.0*random.random()
        #motivation represents a student's motivation for growth 
        self.motivation = school_quailty - 1.0 + 2.0*random.random()
        #consistency represents a student's consistency in performance
        self.consistency = school_quailty - 1.0 + 2.0*random.random()
        
    #problemUpdate updates the student's math ability after a correct problem    
    def problemUpdate(self, correct, difficulty):
        if correct:
            #increase mathAbility with a certain probability
            if np.exp(self.intelligence) / (1+np.exp(self.intelligence)) > random.random()
                self.math_ability = self.math_ability + difficulty/100.0
            #increase intelligence with a certain probability
            if np.exp(self.intelligence) / (1+np.exp(self.intelligence)) > random.random()
                self.intelligence = self.intelligence + difficulty/1000.0
            #increase consistency with a certain probability
            if np.exp(self.intelligence)/(1+np.exp(self.intelligence)) > random.random()
                self.consistency = self.consistency + difficulty/1000.0
            #increase motivation with a certain probability
            if np.exp(self.motivation)/(1+np.exp(self.motivation)) > random.random()
                self.motivation = self.motivation + difficulty/100.0
        else:
            #increase mathAbility with a certain probability
            if np.exp(self.intelligence)/(1+np.exp(self.intelligence)) > random.random()
                self.math_ability = self.math_ability - difficulty/ 100.0
            #increase intelligence with a certain probability
            if np.exp(self.intelligence)/(1+np.exp(self.intelligence)) > random.random()
                self.intelligence = self.intelligence - difficulty/1000.0
            #increase consistency with a certain probability
            if np.exp(self.intelligence)/(1+np.exp(self.intelligence)) > random.random()
                self.consistency = self.consistency - difficulty/1000.0
            #increase motivation with a certain probability
            if np.exp(self.motivation)/(1+np.exp(self.motivation)) > random.random()
                self.motivation = self.motivation - difficulty/100.0

class School:
    def __init__(self,name):
        self.name = name
        self.student = []

class Homework:
    def __init__(self,course,number):
        self.course=course
        self.number=number
        self.problemSet=[]
        
class Problem:
    def __init__(self,topic,dicipline,difficulty,percievedDifficulty):
        self.topic=topic
        self.discipline=discipline
        self.percievedDifficulty=percievedDifficulty
        self.difficulty=difficulty
